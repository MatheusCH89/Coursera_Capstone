# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# ## Clustering Toronto boroughs

# %% [markdown]
# Firstly, Folium is installed and libs are imported

# %%
# !conda install -c conda-forge folium --yes
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.7.0                      py_0    conda-forge

# %%
import pandas as pd
import numpy as np

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %% [markdown]
# Then, the csv file conatining the postal code, boroughs, neighborhoods and its coordinates is imported and a dataframe is obtained

# %%
file = project.get_file("TorontoPostalWithLatlong.csv")
df_postal = pd.read_csv(file)
df_postal.head()
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.806686
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# Now I will use four square to analyze the boroughs and its venues

# %%
CLIENT_ID = 'BDY4WQB5QWKM2ESW5IPRHY3SX0MCEDGDP4FBDDIABQF0WHS4' # your Foursquare ID
CLIENT_SECRET = 'YSIK45TZZKLCUI0COWRGDTCB0JJL4QXJ30JZBLCVEY3ZTJKK' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 30

# %% [markdown]
# Now I will use the function from the labs to get the nearby venues for every borough

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
       # print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
venues = getNearbyVenues(df_postal['Neighborhood'],df_postal['Latitude'],df_postal['Longitude'],500)
venues.head(40)
# Out:
#                                        Neighborhood  Neighborhood Latitude  \
# 0                                    Rouge, Malvern              43.806686
# 1            Highland Creek, Rouge Hill, Port Union              43.784535
# 2                 Guildwood, Morningside, West Hill              43.763573
# 3                 Guildwood, Morningside, West Hill              43.763573
# 4                 Guildwood, Morningside, West Hill              43.763573
# 5                 Guildwood, Morningside, West Hill              43.763573
# 6                 Guildwood, Morningside, West Hill              43.763573
# 7                 Guildwood, Morningside, West Hill              43.763573
# 8                                            Woburn              43.770992
# 9                                            Woburn              43.770992
# 10                                           Woburn              43.770992
# 11                                        Cedarbrae              43.773136
# 12                                        Cedarbrae              43.773136
# 13                                        Cedarbrae              43.773136
# 14                                        Cedarbrae              43.773136
# 15                                        Cedarbrae              43.773136
# 16                                        Cedarbrae              43.773136
# 17                                        Cedarbrae              43.773136
# 18                              Scarborough Village              43.744734
# 19                              Scarborough Village              43.744734
# 20      East Birchmount Park, Ionview, Kennedy Park              43.727929
# 21      East Birchmount Park, Ionview, Kennedy Park              43.727929
# 22      East Birchmount Park, Ionview, Kennedy Park              43.727929
# 23      East Birchmount Park, Ionview, Kennedy Park              43.727929
# 24      East Birchmount Park, Ionview, Kennedy Park              43.727929
# 25      East Birchmount Park, Ionview, Kennedy Park              43.727929
# 26      East Birchmount Park, Ionview, Kennedy Park              43.727929
# 27      East Birchmount Park, Ionview, Kennedy Park              43.727929
# 28                  Clairlea, Golden Mile, Oakridge              43.711112
# 29                  Clairlea, Golden Mile, Oakridge              43.711112
# 30                  Clairlea, Golden Mile, Oakridge              43.711112
# 31                  Clairlea, Golden Mile, Oakridge              43.711112
# 32                  Clairlea, Golden Mile, Oakridge              43.711112
# 33                  Clairlea, Golden Mile, Oakridge              43.711112
# 34                  Clairlea, Golden Mile, Oakridge              43.711112
# 35                  Clairlea, Golden Mile, Oakridge              43.711112
# 36                  Clairlea, Golden Mile, Oakridge              43.711112
# 37  Cliffcrest, Cliffside, Scarborough Village West              43.716316
# 38  Cliffcrest, Cliffside, Scarborough Village West              43.716316
# 39                      Birch Cliff, Cliffside West              43.692657
#
#     Neighborhood Longitude                             Venue  Venue Latitude  \
# 0               -79.194353                           Wendy's       43.807448
# 1               -79.160497             Royal Canadian Legion       43.782533
# 2               -79.188711   Swiss Chalet Rotisserie & Grill       43.767697
# 3               -79.188711                 G & G Electronics       43.765309
# 4               -79.188711                  Big Bite Burrito       43.766299
# 5               -79.188711             Enterprise Rent-A-Car       43.764076
# 6               -79.188711             Woburn Medical Centre       43.766631
# 7               -79.188711                          Eggsmart       43.767800
# 8               -79.216917                         Starbucks       43.770037
# 9               -79.216917                       Tim Hortons       43.770827
# 10              -79.216917                Korean Grill House       43.770812
# 11              -79.239476               Federick Restaurant       43.774697
# 12              -79.239476          Drupati's Roti & Doubles       43.775222
# 13              -79.239476                       Thai One On       43.774468
# 14              -79.239476      Centennial Recreation Centre       43.774593
# 15              -79.239476                   TD Canada Trust       43.774952
# 16              -79.239476                        B&A Bakery       43.774391
# 17              -79.239476         Popeyes Louisiana Kitchen       43.775930
# 18              -79.239476                      McCowan Park       43.745089
# 19              -79.239476   True Discount Convenience Store       43.743854
# 20              -79.262029                       Giant Tiger       43.727447
# 21              -79.262029                       Tim Hortons       43.726895
# 22              -79.262029                 Bros. CONVENIENCE       43.727781
# 23              -79.262029                        Hakka No.1       43.727688
# 24              -79.262029                         Dollarama       43.726904
# 25              -79.262029                Kennedy GO Station       43.732275
# 26              -79.262029                         Dollarama       43.726657
# 27              -79.262029  Kennedy Station Passenger Pickup       43.732009
# 28              -79.284577                       Dairy Queen       43.710378
# 29              -79.284577      Warden Ave & St. Clair Ave E       43.712057
# 30              -79.284577                TTC Bus #68 Warden       43.711778
# 31              -79.284577          TTC Bus 102 Markham Road       43.711381
# 32              -79.284577           Warden Station Bus Loop       43.711241
# 33              -79.284577                  Bakery On The Go       43.711271
# 34              -79.284577                    Cafe on the go       43.711151
# 35              -79.284577                 Warden Woods Park       43.710527
# 36              -79.284577            Clairlea Futbol Centre       43.715234
# 37              -79.239476                  Have A Nap Motel       43.718256
# 38              -79.239476                    Vincent's Spot       43.717002
# 39              -79.264848                    The Birchcliff       43.691666
#
#     Venue Longitude        Venue Category
# 0        -79.199056  Fast Food Restaurant
# 1        -79.163085                   Bar
# 2        -79.189914           Pizza Place
# 3        -79.191537     Electronics Store
# 4        -79.190720    Mexican Restaurant
# 5        -79.193406   Rental Car Location
# 6        -79.192286        Medical Center
# 7        -79.190466        Breakfast Spot
# 8        -79.221156           Coffee Shop
# 9        -79.223078           Coffee Shop
# 10       -79.214502     Korean Restaurant
# 11       -79.241142      Hakka Restaurant
# 12       -79.241678  Caribbean Restaurant
# 13       -79.241268       Thai Restaurant
# 14       -79.236500    Athletics & Sports
# 15       -79.241343                  Bank
# 16       -79.243877                Bakery
# 17       -79.235328   Fried Chicken Joint
# 18       -79.239336            Playground
# 19       -79.244650     Convenience Store
# 20       -79.266240      Department Store
# 21       -79.266157           Coffee Shop
# 22       -79.265708     Convenience Store
# 23       -79.266057    Chinese Restaurant
# 24       -79.265886        Discount Store
# 25       -79.262418         Train Station
# 26       -79.266717        Discount Store
# 27       -79.264537           Bus Station
# 28       -79.290701  Fast Food Restaurant
# 29       -79.281005          Intersection
# 30       -79.279714              Bus Line
# 31       -79.279588              Bus Line
# 32       -79.279576           Bus Station
# 33       -79.279506                Bakery
# 34       -79.279469                Bakery
# 35       -79.278966                  Park
# 36       -79.286506          Soccer Field
# 37       -79.240135                 Motel
# 38       -79.242353   American Restaurant
# 39       -79.264532                  Café

# %% [markdown]
# Well, I love coffee, so now I will get only the coffee shops on my venues dataframe

# %%
venuesCoffee = venues.loc[venues['Venue Category'] == 'Coffee Shop']
coffeeFreq = venuesCoffee.groupby(['Neighborhood','Neighborhood Latitude','Neighborhood Longitude'])['Venue Category'].agg({'Coffee shops':'count'})
coffeeFreq.reset_index()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   from ipykernel import kernelapp as app
#                                          Neighborhood  Neighborhood Latitude  \
# 0                            Adelaide, King, Richmond              43.650571
# 1   Albion Gardens, Beaumond Heights, Humbergate, ...              43.739416
# 2                              Alderwood, Long Branch              43.602414
# 3     Bathurst Manor, Downsview North, Wilson Heights              43.754328
# 4                   Bedford Park, Lawrence Manor East              43.733283
# 5        Brockton, Exhibition Place, Parkdale Village              43.636847
# 6                         Cabbagetown, St. James Town              43.667967
# 7               Canada Post Gateway Processing Centre              43.636966
# 8                                  Central Bay Street              43.657952
# 9           Chinatown, Grange Park, Kensington Market              43.653206
# 10                                           Christie              43.669542
# 11                               Church and Wellesley              43.665860
# 12                     Commerce Court, Victoria Hotel              43.648198
# 13                                         Davisville              43.704324
# 14  Deer Park, Forest Hill SE, Rathnelly, South Hi...              43.686412
# 15     Del Ray, Keelesdale, Mount Dennis, Silverthorn              43.691116
# 16           Design Exchange, Toronto Dominion Centre              43.647177
# 17                       Dovercourt Village, Dufferin              43.669005
# 18        East Birchmount Park, Ionview, Kennedy Park              43.727929
# 19                       Fairview, Henry Farm, Oriole              43.778517
# 20             First Canadian Place, Underground city              43.648429
# 21                   Flemingdon Park, Don Mills South              43.725900
# 22                     Harbord, University of Toronto              43.662696
# 23                          Harbourfront, Regent Park              43.654260
# 24       Humber Bay Shores, Mimico South, New Toronto              43.605647
# 25                      L'Amoreaux West, Steeles West              43.799525
# 26                   Lawrence Heights, Lawrence Manor              43.718518
# 27                                            Leaside              43.709060
# 28                           Little Portugal, Trinity              43.647927
# 29                                 North Toronto West              43.715383
# 30                    Northwood Park, York University              43.767980
# 31                             Parkdale, Roncesvalles              43.648960
# 32                                       Queen's Park              43.662301
# 33                                 Runnymede, Swansea              43.651571
# 34                           Ryerson, Garden District              43.657162
# 35                                     St. James Town              43.651494
# 36                    Stn A PO Boxes 25 The Esplanade              43.646435
# 37                                    Studio District              43.659526
# 38                The Annex, North Midtown, Yorkville              43.672710
# 39                                        The Beaches              43.676357
# 40                                   Thorncliffe Park              43.705369
# 41                                   Victoria Village              43.725882
# 42                                          Westmount              43.696319
# 43                                   Willowdale South              43.770120
# 44                                    Willowdale West              43.782736
# 45                                             Woburn              43.770992
#
#     Neighborhood Longitude  Coffee shops
# 0               -79.384568             1
# 1               -79.588437             1
# 2               -79.543484             1
# 3               -79.442259             2
# 4               -79.419750             2
# 5               -79.428191             2
# 6               -79.367675             2
# 7               -79.615819             2
# 8               -79.387383             7
# 9               -79.400049             1
# 10              -79.422564             1
# 11              -79.383160             1
# 12              -79.379817             3
# 13              -79.388790             2
# 14              -79.400049             2
# 15              -79.476013             1
# 16              -79.381576             4
# 17              -79.442259             1
# 18              -79.262029             1
# 19              -79.346556             2
# 20              -79.382280             3
# 21              -79.340923             2
# 22              -79.400049             2
# 23              -79.360636             5
# 24              -79.501321             1
# 25              -79.318389             1
# 26              -79.464763             1
# 27              -79.363452             3
# 28              -79.419750             1
# 29              -79.405678             2
# 30              -79.487262             1
# 31              -79.456325             1
# 32              -79.389494             5
# 33              -79.484450             3
# 34              -79.378937             2
# 35              -79.375418             2
# 36              -79.374846             1
# 37              -79.340923             3
# 38              -79.405678             3
# 39              -79.293031             1
# 40              -79.349372             1
# 41              -79.315572             1
# 42              -79.532242             1
# 43              -79.408493             2
# 44              -79.442259             1
# 45              -79.216917             2

# %% [markdown]
# Now I will count how many coffee shops are in each neighborhood

# %% [markdown]
# ## Now I want to cluster the neighborhoods by the amount of coffee shops

# %% [markdown]
# I want to know the places in a map in which i will have more options to drink coffee

# %% [markdown]
# Now the K means algorithm is used to cluster the dataframe entries. I opted to use every entry from the table and not just the ones that have 'Toronto' in the borough field.
# It will be used four clusters in the algorithm.

# %%
# set number of clusters
kclusters = 3

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(coffeeFreq[['Coffee shops']])

# check cluster labels generated for each row in the dataframe
#kmeans.labels_[0:10]

coffeeFreq['Cluster ID'] = kmeans.labels_
coffeeFreq = coffeeFreq.reset_index()
coffeeFreq.head(30)
# Out:
#                                          Neighborhood  Neighborhood Latitude  \
# 0                            Adelaide, King, Richmond              43.650571
# 1   Albion Gardens, Beaumond Heights, Humbergate, ...              43.739416
# 2                              Alderwood, Long Branch              43.602414
# 3     Bathurst Manor, Downsview North, Wilson Heights              43.754328
# 4                   Bedford Park, Lawrence Manor East              43.733283
# 5        Brockton, Exhibition Place, Parkdale Village              43.636847
# 6                         Cabbagetown, St. James Town              43.667967
# 7               Canada Post Gateway Processing Centre              43.636966
# 8                                  Central Bay Street              43.657952
# 9           Chinatown, Grange Park, Kensington Market              43.653206
# 10                                           Christie              43.669542
# 11                               Church and Wellesley              43.665860
# 12                     Commerce Court, Victoria Hotel              43.648198
# 13                                         Davisville              43.704324
# 14  Deer Park, Forest Hill SE, Rathnelly, South Hi...              43.686412
# 15     Del Ray, Keelesdale, Mount Dennis, Silverthorn              43.691116
# 16           Design Exchange, Toronto Dominion Centre              43.647177
# 17                       Dovercourt Village, Dufferin              43.669005
# 18        East Birchmount Park, Ionview, Kennedy Park              43.727929
# 19                       Fairview, Henry Farm, Oriole              43.778517
# 20             First Canadian Place, Underground city              43.648429
# 21                   Flemingdon Park, Don Mills South              43.725900
# 22                     Harbord, University of Toronto              43.662696
# 23                          Harbourfront, Regent Park              43.654260
# 24       Humber Bay Shores, Mimico South, New Toronto              43.605647
# 25                      L'Amoreaux West, Steeles West              43.799525
# 26                   Lawrence Heights, Lawrence Manor              43.718518
# 27                                            Leaside              43.709060
# 28                           Little Portugal, Trinity              43.647927
# 29                                 North Toronto West              43.715383
#
#     Neighborhood Longitude  Coffee shops  Cluster ID
# 0               -79.384568             1           0
# 1               -79.588437             1           0
# 2               -79.543484             1           0
# 3               -79.442259             2           2
# 4               -79.419750             2           2
# 5               -79.428191             2           2
# 6               -79.367675             2           2
# 7               -79.615819             2           2
# 8               -79.387383             7           1
# 9               -79.400049             1           0
# 10              -79.422564             1           0
# 11              -79.383160             1           0
# 12              -79.379817             3           2
# 13              -79.388790             2           2
# 14              -79.400049             2           2
# 15              -79.476013             1           0
# 16              -79.381576             4           1
# 17              -79.442259             1           0
# 18              -79.262029             1           0
# 19              -79.346556             2           2
# 20              -79.382280             3           2
# 21              -79.340923             2           2
# 22              -79.400049             2           2
# 23              -79.360636             5           1
# 24              -79.501321             1           0
# 25              -79.318389             1           0
# 26              -79.464763             1           0
# 27              -79.363452             3           2
# 28              -79.419750             1           0
# 29              -79.405678             2           2

# %% [markdown]
# Now the map is created, with every borough highlighted and assigned with a determined cluster

# %%
latitude = coffeeFreq['Neighborhood Latitude'][0]
longitude = coffeeFreq['Neighborhood Longitude'][0]

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster, qty in zip(coffeeFreq['Neighborhood Latitude'], coffeeFreq['Neighborhood Longitude'], coffeeFreq['Neighborhood'], coffeeFreq['Cluster ID'], coffeeFreq['Coffee shops']):
    label = folium.Popup(str(poi) + ' - ' + str(qty) + " coffee shops", parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
